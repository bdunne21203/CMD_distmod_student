# %% [markdown]
# **Name**:

# %% [markdown]
# # Main sequence fitting of clusters (40 points)
#
# I expect that you will be able to complete most of the work in class.  If you do not, you have till **weds. Sept. 20** to hand it in.  Instructions on how to do so are at the end of the document.
#
# This exercise is intended to give you a practical exercise in determining the distance to star clusters in the milky way.  You will do this by plotting the color-magnitude diagrams of 4 clusters compared to that of a cluster with a known distances.  This "reference" cluster is the nearby Pleiades (M 45), which is visible to the naked eye in late fall/winter.  It has a distance of 130pc.
#
# There are four other clusters that you will be studying:<br>
# M 34<br>
# M 36<br>
# NGC 6231<br>
# NGC 3293<br>
#
# I have written a program to plot the color magnitude diagram of each cluster on top of the Plieades cluster.  You run this code by typing:
#
# *cp.cmdplot(clustname='cluster name',magshift=0.0,colshift=0.0)*
#
# For each cluster you will use the code to plot that cluster and input color and magnitude shifts to align the cluster with the Pleiades.  Using your knowledge of how distance affects color and magnitude, you will need to decide if you use color shifts, magnitude shifts, or both.
#
# Using these shifts you will write a snippet of code below each plot in the space provided.  This code should be a short calculation to determine what the distance is based on the shifts.
#
# _Note that it is not required that color and magnitude shifts be used in your calculation.  You get to decide which are important._
#
# In order to get full credit for this assignment all cells have to execute without errors.  You also need to fill out the cells at the bottom and add code where required
#
# The colors and magnitudes being used in this program are called GRP and GBP.  These stand for "GAIA Red Passband" and "GAIA Blue Passband" and are custome filters used for the GAIA mission.
#
# All sections of code that you need to work on will be indicated by a '#### Write code here'

# %%
import cluster_plot as cp
import numpy as np
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## From here onward is the assignment
#
# #### M34 (3 points)

# %%
cp.cmdplot(clustname='M 34',magshift=-2.75,colshift=0.0)

# %% [markdown]
# In this cell, describe what you chose for your shifts and why.
# I chose to shift the magnitude given Pleiades is at a differnt distance than M 34 meaning the apparent magnitude will be different because magnitude is related to distance, where objects of the same absolute magnitude will have different apparent magnitudes at different distances. I did not shift color given it is defined as the difference in two magnitudes and will always be independent of distance. Both color magnitudes will scale by the same amount when distance is changed, leaving their difference identical.

# %% [markdown]
# Use the derived shifts to compute a distance to the cluster by writing a small snippet of code

# %%
#write a calculation here that you execute and which prints out the distance to your cluster in pc.  
#To compute the log_10 you need to write "np.log10(number)"
#### Write code here.
# enter your calculated shift here
#shif for M_34 estimated to be -2.75 mag shift based on imputting different values in the plot above
shift_m34 = -2.75

# Assuming the distance to M45 is 130pc write an code expression that converts your shift into the ratio of the distances 
#the Pleiades to this cluster
#define dist_ratio_m34 as 10^(-mag shift/5) based on sloving for distance ratio based on m-M=-2.5log(d)-5
dist_ratio_m34 = 10**((-shift_m34)/(5))
#define dist_m34 as distance ratio*130 given m 45 is 130 pc away to estimate distance
dist_m34= dist_ratio_m34*130
#display dist_m34 as distance to M34 (pc)
print('distance to M34 (pc)=',dist_m34)
print(dist_ratio_m34)
# Out:
# distance to M34 (pc)= 461.25740600364816
# 3.548133892335755

# %% [markdown]
# #### M 36 (3 points)

# %%
cp.cmdplot(clustname='M 36',magshift=-4.15,colshift=0.0)

# %% [markdown]
# In this cell, describe what you chose for your shifts and why. I chose to shift the magnitude given Pleiades is at a differnt distance than M 36 meaning the apparent magnitude will be different because magnitude is related to distance, where objects of the same absolute magnitude will have different apparent magnitudes at different distances. I did not shift color given it is defined as the difference in two magnitudes and will always be independent of distance. Both color magnitudes will scale by the same amount when distance is changed, leaving their difference identical.

# %% [markdown]
# Use the derived magnitude shift to compute a distance to the cluster by writing a small snippet of code

# %%
#write a calculation here that you execute and which prints out the distance to your cluster in pc.  
#To compute the log_10 you need to write "np.log10(number)"
#### Write code here.
# enter your calculated shift here
#shif for M_34 estimated to be -4.15 mag shift based on imputting different values in the plot above
shift_m36 = -4.15

# Assuming the distance to M45 is 130pc write an code expression that converts your shift into the ratio of the distances 
#the Pleiades to this cluster
#define dist_ratio_m36 as 10^(-mag shift/5) based on sloving for distance ratio based on m-M=-2.5log(d)-5
dist_ratio_m36 = 10**((-shift_m36)/(5))
#define dist_m36 as distance ratio*130 given m 45 is 130 pc away to estimate distance
dist_m36= dist_ratio_m36*130
#display dist_m36 as distance to M36 (pc)
print('distance to M36 (pc)=',dist_m36) 
print(dist_ratio_m36)
# Out:
# distance to M36 (pc)= 878.9078680095765
# 6.760829753919819

# %% [markdown]
# #### NGC 6231  (3 points)

# %%
cp.cmdplot(clustname='NGC 6231',magshift=-3.3,colshift=0.0)

# %% [markdown]
# In this cell, describe what you chose for your shifts and why.
# I chose to shift the magnitude given Pleiades is at a differnt distance than NGC 6231 meaning the apparent magnitude will be different because magnitude is related to distance, where objects of the same absolute magnitude will have different apparent magnitudes at different distances. I did not shift color given it is defined as the difference in two magnitudes and will always be independent of distance. Both color magnitudes will scale by the same amount when distance is changed, leaving their difference identical.

# %% [markdown]
# Use the derived magnitude shift to compute a distance to the cluster by writing a small snippet of code

# %%
#write a calculation here that you execute and which prints out the distance to your cluster in pc.  
#To compute the log_10 you need to write "np.log10(number)"
#### Write code here.

# enter your calculated shift here
#shif for M_34 estimated to be -3.30 mag shift based on imputting different values in the plot above
shift_ngc6231 = -3.30

# Assuming the distance to M45 is 130pc write an code expression that converts your shift into the ratio of the distances 
#the Pleiades to this cluster
#define dist_ratio_ngc6231 as 10^(-mag shift/5) based on sloving for distance ratio based on m-M=-2.5log(d)-5
dist_ratio_ngc6231 = 10**((-shift_ngc6231)/(5))
#define dist_ngc6231 as distance ratio*130 given m 45 is 130 pc away to estimate distance
dist_ngc6231= dist_ratio_ngc6231*130
#display dist_ngc6231 as distance to NGC 6231 (pc)
print('distance to NGC 6231 (pc)=',dist_ngc6231)
print(dist_ratio_ngc6231)
# Out:
# distance to NGC 6231 (pc)= 594.2146464993375
# 4.57088189614875

# %% [markdown]
# #### NGC 3293  (3 points)

# %%
cp.cmdplot(clustname='ngc 3293',magshift=-5.25,colshift=0.0)

# %% [markdown]
# In this cell, describe what you chose for your shifts and why.
# I chose to shift the magnitude given Pleiades is at a differnt distance than NGC 3293 meaning the apparent magnitude will be different because magnitude is related to distance, where objects of the same absolute magnitude will have different apparent magnitudes at different distances. I did not shift color given it is defined as the difference in two magnitudes and will always be independent of distance. Both color magnitudes will scale by the same amount when distance is changed, leaving their difference identical.

# %% [markdown]
# Use the derived magnitude shift to compute a distance to the cluster by writing a small snippet of code

# %%
#write a calculation here that you execute and which prints out the distance to your cluster in pc.  
#To compute the log_10 you need to write "np.log10(number)"
#### Write code here.

# enter your calculated shift here
#shif for M_34 estimated to be -5.25 mag shift based on imputting different values in the plot above
shift_ngc3293 = -5.25

# Assuming the distance to M45 is 130pc write an code expression that converts your shift into the ratio of the distances 
#the Pleiades to this cluster
#define dist_ratio_ngc3239 as 10^(-mag shift/5) based on sloving for distance ratio based on m-M=-2.5log(d)-5
dist_ratio_ngc3293 = 10**((-shift_ngc3293)/(5))
#define dist_ngc3239 as distance ratio*130 given m 45 is 130 pc away to estimate distance
dist_ngc3293= dist_ratio_ngc3293*130
#display dist_ngc3239 as distance to NGC 3239 (pc)
print('distance to NGC 3239 (pc)=',dist_ngc3293)
print(dist_ratio_ngc3293)
# Out:
# distance to NGC 3239 (pc)= 1458.6239905925527
# 11.220184543019636

# %% [markdown]
# # plotting distances vs. distance modulus  (12 points)
# If the distance to the Pleiades cluster is 130pc, compute the distance modulus to each cluster.  You can do the algebra on a separate piece of paper, but below I want you to code up the formula for each cluster in the field below

# %%
#For each cluster put in a line of code that calculates the distance modulus.  I have given part of the code below and expect you to fill it in.

#this creates a python array that contains all of the distance ratios you calculated above.  
#Now you can do operations on this array and it will operate on every element
dist_ratios = np.array([dist_ratio_m34, dist_ratio_m36, dist_ratio_ngc6231, dist_ratio_ngc3293])

#### Write code here.

#write an expression to calculate the distance to each cluster
dist_pleiades = 130.0
#define dists as distance to pleiades (130 pc)*the array of distance moduli (dist_ratios)
dists = dist_pleiades*dist_ratios

print("Distance for M 34 = ", dists[0], " pc")
print("Distance for M 36 = ", dists[1], " pc")
print("Distance for NGC 6231 = ", dists[2], " pc")
print("Distance for NGC 3293 = ", dists[3], " pc")
print()

#write an expression to derive the distance modulus from the distance ratio or distance
#define dist_mods as 5*log(the distance array/10) based on equation from notes (m-M=distance modulus)
dist_mods = 5*np.log10(dists/10)

print("Distance Modulus for M 34 = ", dist_mods[0])
print("Distance Modulus for M 36 = ", dist_mods[1])
print("Distance Modulus for NGC 6231 = ", dist_mods[2])
print("Distance Modulus for NGC 3293 = ", dist_mods[3])
# Out:
# Distance for M 34 =  461.25740600364816  pc
# Distance for M 36 =  878.9078680095765  pc
# Distance for NGC 6231 =  594.2146464993375  pc
# Distance for NGC 3293 =  1458.6239905925527  pc
#
# Distance Modulus for M 34 =  8.319716761534185
# Distance Modulus for M 36 =  9.719716761534185
# Distance Modulus for NGC 6231 =  8.869716761534184
# Distance Modulus for NGC 3293 =  10.819716761534185

# %% [markdown]
# Now make a plot of the Distance modulus you calculated above vs. the log10 of the distance.  I will write some of the code below and you will need to fill it in to get the appropriate values.
#
# I then want you to overplot the relation that you would expect given the relation between distance and distance modulus
#
# In the `plot` statement below there are missing arguments.  the `'ko', markersize=9)` part of the call indicates that you should have black circles (`'ko'`) and that the size of the points should be 9, in whatever units pyplot uses (bigger number = larger points)

# %%
#You will need to make an array that contains the log of the distances

#### Write code here
#define logdist as the logorithym of the distance array (dists)
logdist = np.log10(dists)

#now complete this plot statement to plot the log of the distance vs. the distance modulus.
#plot log distance on x axis, distance mod on y axis, with black circles with point size 9
plt.plot( logdist,dist_mods,'ko', markersize=9)
plt.xlabel('log(distance [pc])')
plt.ylabel('Distance modulus')

# here you will need to draw a line on your plot that shows the prediction
#of the distance modulus given the distance.
#these are the two x-points of your line, in log distance
logdistpred = np.array([2,4])

# write down the function that turns logdistpred into the distance modulus
#define dmpred as 5 times the array logdistpred -5
dmpred = 5*logdistpred-5

#plot this line on the previous plot
#the 'r-' indicates a red line
plt.plot(logdistpred, dmpred, 'r-')

# %% [markdown]
# ### below this line you need to modify the cells and include text  (16 points)
#
# In each cell add text to answer the following questions

# %% [markdown]
# - How the line you plotted matches (or not) the trend you see in the data. The plot of data matches nearly perfectly onto the expected trend. This indicates that the distance modulus has a linear relationship with the logorithim of the distance in parsecs.

# %% [markdown]
# - Why do more distant clusters have more stars? Note that I used parallaxes to make a cut of roughly 30% in distance around each cluster.  This means I took the mean distance of the cluster and took stars between 70\% and 130\% of that distance.
# For clusters that are further away, 30% of that mean distance is a larger value than 30% of the  mean distance to a closer cluster, meaning for those clusters at a greater distance we are counting stars over a greater distance, so we should be counting more total stars.

# %% [markdown]
# - What astrophysical effect that we are ignoring might affect our derived distances and in what way? We are ignoring interstellar reddening and extintion, which is caused by tiny dust particles absorbing or reflecting light at certain wavelengths. This would dim the light from the cluster, making our calculations of distance be too large compared to the actual distance given the flux will be lower than it would be if there were no dust in the galaxy.

# %% [markdown]
# - How might you do a better job determining the shifts than doing it by eye.  If you would like to try it out your method, you can take some of the data files in the Project_clusters/ directory and try to implement a better method.  The quantities we use to make the plots are bp_rp for the x-axis and phot_rp_mean_mag for the y-axis. Stars with the same GBP-GBR should have the same spectral type given the color is related to the surface temperature, which is in turn related to spectral type. This means you could use a boolean selection for small increments in the GBP-GBR axis to find stars of similar spectral types from both Pleiades and the comparison cluster. You could define a flag such as flag1= bp_rp > -0.5 & bp_rp < -0.25 and index it like a=bp_rp[flag1]. From there you can use the np.average function to find the average magnitude of both Pleiades and the other cluster over the boolean selection. The magnitudes can be found by on indexing all points from phot_rp_mean_mag in the boolean range (a in this case). From there, you could subtract the other clusters average magnitude from Pleiades average magnitude to find the shift. Then repeat these steps for boolean selections that go over the entire range, create a new array of all the average shifts, and use np.average to find a total average for all average shifts over each boolean range.
#
# ***Hint***: There are functions in numpy, `numpy.median()` and `numpy.average()` that take the mean and median of an array passed to it.  So you could use Boolean commands to select a portion of one of the axes and one of the numpy commands to compute the median or average value of the other parameter.

# %% [markdown]
# ## Instructions for handing the assignment in
#
# Make sure to save your notebook.
#
# Add this file to your CMD_fitting_distance_modulus github repository.
#
# No need to add me as a collaborator.  As long as you named the exercise accordingly I will be able to find it in your repository.
